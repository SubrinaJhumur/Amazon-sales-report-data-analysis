# %% [markdown]
#  importing all the necessary librabies for the data analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#loading the dataset
data=pd.read_csv(r'C:\Users\User\Desktop\data_hub\Amazon Sale Report.csv')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_5076\814397100.py:2: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv(r'C:\Users\User\Desktop\data_hub\Amazon Sale Report.csv')

# %%
#showing the first 3 rows of the whole dataset
data.head(3)
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
#
#   Category  ... currency  Amount    ship-city   ship-state ship-postal-code  \
# 0      Set  ...      INR  647.62       MUMBAI  MAHARASHTRA         400081.0
# 1    kurta  ...      INR  406.00    BENGALURU    KARNATAKA         560085.0
# 2    kurta  ...      INR  329.00  NAVI MUMBAI  MAHARASHTRA         410210.0
#
#    ship-country                                      promotion-ids    B2B  \
# ...

# %%
#show how many rows and how many columns are in the whole dataset
data.shape
# Out:
# (128975, 24)

# %%
#with is function we can see the columns name
data.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %%
# show the last 3 rows  of the whole dataset 
data.tail(3)
# Out:
#          index             Order ID      Date   Status Fulfilment  \
# 128972  128972  407-9547469-3152358  05-31-22  Shipped     Amazon
# 128973  128973  402-6184140-0545956  05-31-22  Shipped     Amazon
# 128974  128974  408-7436540-8728312  05-31-22  Shipped     Amazon
#
#        Sales Channel  ship-service-level  Style           SKU       Category  \
# 128972      Amazon.in          Expedited  J0157  J0157-DR-XXL  Western Dress
# 128973      Amazon.in          Expedited  J0012  J0012-SKD-XS            Set
# 128974      Amazon.in          Expedited  J0003   J0003-SET-S            Set
#
#         ... currency  Amount  ship-city    ship-state ship-postal-code  \
# 128972  ...      INR   690.0  HYDERABAD     TELANGANA         500049.0
# 128973  ...      INR  1199.0      Halol       Gujarat         389350.0
# 128974  ...      INR   696.0     Raipur  CHHATTISGARH         492014.0
#
#         ship-country                                 promotion-ids    B2B  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
# ...

# %%
#dropping the unnecessary columns
data.drop(columns=['Style', 'SKU','ASIN','promotion-ids'],axis=1,inplace=True)

# %%
#after dropping the columns what is the shape of the dataset
data.shape
# Out:
# (128975, 20)

# %%
#getting the overall information of the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 20 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Category            128975 non-null  object
#  8   Size                128975 non-null  object
#  9   Courier Status      122103 non-null  object
#  10  Qty                 128975 non-null  int64
#  11  currency            121180 non-null  object
#  12  Amount              121180 non-null  float64
#  13  ship-city           128942 non-null  object
#  14  ship-state          128942 non-null  object
# ...

# %%
#code to show how many columns having how many numbers of missing values
data.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Category                  0
# Size                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# B2B                       0
# fulfilled-by          89698
# Unnamed: 22           49050
# dtype: int64

# %%
#with heatmap we can watch how many data are missing with picture
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
#drop a certain column having a huge amount of missing values
data.drop(columns=['fulfilled-by'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 2
#       1 #drop a certain column having a huge amount of missing values
# ----> 2 data.drop(columns=['fulfilled-by'],axis=1,inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
# ...

# %%
# after dropping all the missing values
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
# dropping the missing values
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# index                 0
# Order ID              0
# Date                  0
# Status                0
# Fulfilment            0
# Sales Channel         0
# ship-service-level    0
# Category              0
# Size                  0
# Courier Status        0
# Qty                   0
# currency              0
# Amount                0
# ship-city             0
# ship-state            0
# ship-postal-code      0
# ship-country          0
# B2B                   0
# Unnamed: 22           0
# dtype: int64

# %%
data.shape
# Out:
# (72095, 19)

# %%
128975-72095
# Out:
# 56880

# %%
data.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Qty',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B', 'Unnamed: 22'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 72095 entries, 49050 to 128974
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               72095 non-null  int64
#  1   Order ID            72095 non-null  object
#  2   Date                72095 non-null  object
#  3   Status              72095 non-null  object
#  4   Fulfilment          72095 non-null  object
#  5   Sales Channel       72095 non-null  object
#  6   ship-service-level  72095 non-null  object
#  7   Category            72095 non-null  object
#  8   Size                72095 non-null  object
#  9   Courier Status      72095 non-null  object
#  10  Qty                 72095 non-null  int64
#  11  currency            72095 non-null  object
#  12  Amount              72095 non-null  float64
#  13  ship-city           72095 non-null  object
#  14  ship-state          72095 non-null  object
# ...

# %%
# change data type
data['ship-postal-code']=data['ship-postal-code'].astype('int')

# %%
data['ship-postal-code'].dtypes
# Out:
# dtype('int32')

# %%
data['Date']=pd.to_datetime(data['Date'])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_5076\1428478067.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Date']=pd.to_datetime(data['Date'])

# %%
data['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 72095 entries, 49050 to 128974
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               72095 non-null  int64
#  1   Order ID            72095 non-null  object
#  2   Date                72095 non-null  datetime64[ns]
#  3   Status              72095 non-null  object
#  4   Fulfilment          72095 non-null  object
#  5   Sales Channel       72095 non-null  object
#  6   ship-service-level  72095 non-null  object
#  7   Category            72095 non-null  object
#  8   Size                72095 non-null  object
#  9   Courier Status      72095 non-null  object
#  10  Qty                 72095 non-null  int64
#  11  currency            72095 non-null  object
#  12  Amount              72095 non-null  float64
#  13  ship-city           72095 non-null  object
#  14  ship-state          72095 non-null  object
# ...

# %%
data.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Qty',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B', 'Unnamed: 22'],
#       dtype='object')

# %%
data.rename(columns={'Qty':'Quantity'},inplace=True)

# %%
data.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Quantity',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B', 'Unnamed: 22'],
#       dtype='object')

# %%
data.describe(include='object')
# Out:
#                    Order ID   Status Fulfilment Sales Channel   \
# count                 72095    72095      72095          72095
# unique                67229       12          2              1
# top     404-9932919-6662730  Shipped     Amazon      Amazon.in
# freq                     11    48723      52667          72095
#
#        ship-service-level Category   Size Courier Status currency  ship-city  \
# count               72095    72095  72095          72095    72095      72095
# unique                  2        9     11              2        1       6320
# top             Expedited    kurta      M        Shipped      INR  BENGALURU
# freq                52094    27209  12682          67637    72095       6617
#
#          ship-state ship-country Unnamed: 22
# count         72095        72095       72095
# unique           60            1           1
# top     MAHARASHTRA           IN       False
# freq          12606        72095       72095

# %%
data[['Quantity','Amount']].describe()
# Out:
#            Quantity        Amount
# count  72095.000000  72095.000000
# mean       1.003703    663.201207
# std        0.068472    286.897844
# min        1.000000      0.000000
# 25%        1.000000    459.000000
# 50%        1.000000    635.000000
# 75%        1.000000    791.000000
# max        5.000000   3036.000000

# %%
data.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Quantity',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B', 'Unnamed: 22'],
#       dtype='object')

# %%
ax=sns.countplot(x='Size',data=data)

# %% [markdown]
# ### medium size products sold higher than than the other size products

# %%
ax=sns.countplot(x='Size',data=data)
for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# #### from the graph above we can see that most people buy the medium size products most

# %%
data1=data.groupby('Size')['Quantity'].sum().sort_values(ascending=False).reset_index()

# %%
sns.barplot(x='Size',y='Quantity',data=data1)
# Out:
# <Axes: xlabel='Size', ylabel='Quantity'>

# %% [markdown]
# #### in quantity basis most of the products sold in m size products

# %%
data.head(5)
# Out:
#        index             Order ID       Date                        Status  \
# 49050  49050  403-5326073-3735562 2022-05-31                       Shipped
# 49051  49051  408-4858463-2356347 2022-05-31  Shipped - Delivered to Buyer
# 49053  49053  402-5892689-9803563 2022-05-31                       Shipped
# 49055  49055  408-1575008-5742745 2022-05-31                       Shipped
# 49056  49056  408-7491199-9117934 2022-05-31                       Shipped
#
#       Fulfilment Sales Channel  ship-service-level Category Size  \
# 49050     Amazon      Amazon.in          Expedited    kurta  XXL
# 49051   Merchant      Amazon.in           Standard    kurta    M
# 49053     Amazon      Amazon.in          Expedited      Top    L
# 49055     Amazon      Amazon.in          Expedited      Set   XL
# 49056     Amazon      Amazon.in          Expedited      Top  XXL
#
#       Courier Status  Quantity currency  Amount    ship-city      ship-state  \
# ...

# %%
data['Courier Status'].value_counts()
# Out:
# Courier Status
# Shipped      67637
# Unshipped     4458
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
ax=sns.countplot(x='Courier Status',data=data,hue='Status')
#for bars in ax.containers:
    #ax.bar_label(bars)

# %% [markdown]
# #### from this graph we can say that majority of orders are shipped through courier

# %%
data['Size'].hist()
# Out:
# <Axes: >

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 72095 entries, 49050 to 128974
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               72095 non-null  int64
#  1   Order ID            72095 non-null  object
#  2   Date                72095 non-null  datetime64[ns]
#  3   Status              72095 non-null  object
#  4   Fulfilment          72095 non-null  object
#  5   Sales Channel       72095 non-null  object
#  6   ship-service-level  72095 non-null  object
#  7   Category            72095 non-null  object
#  8   Size                72095 non-null  object
#  9   Courier Status      72095 non-null  object
#  10  Quantity            72095 non-null  int64
#  11  currency            72095 non-null  object
#  12  Amount              72095 non-null  float64
#  13  ship-city           72095 non-null  object
#  14  ship-state          72095 non-null  object
# ...

# %%
data['Category']=data['Category'].astype(str)

# %%
data['Category'].value_counts()
# Out:
# Category
# kurta            27209
# Set              27004
# Western Dress    10146
# Top               6224
# Ethnic Dress       739
# Blouse             462
# Bottom             228
# Saree               80
# Dupatta              3
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,4))
sns.countplot(x='Category',data=data)
plt.show()

# %% [markdown]
# #### from the graph we can say that kurta and the set are 2 items sold most

# %%
data2=data['B2B'].value_counts()

# %%
plt.pie(data2,labels=data2,autopct='%1.1f%%')
plt.show()

# %% [markdown]
# #### from the pie chart we can say that 99.3% of buyer are from retailer buyers and only .7% are B2B buyers

# %%
data3=data['Fulfilment'].value_counts()

# %%
#plt.figure(figsize=(12,8))
ax=sns.countplot(x='Fulfilment',data=data)
for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# #### from the graph we can say that maximum number of orders are done through Amazon

# %%
plt.figure(figsize=(12,4))
plt.scatter(x='Category',y='Size',data=data)
plt.xlabel('Category')
plt.ylabel('Size')
plt.show()

# %% [markdown]
# #### from the scatter plot we can say that kurta and set are sold most

# %%
data.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Quantity',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B', 'Unnamed: 22'],
#       dtype='object')

# %%
data4=data['ship-state'].value_counts().reset_index()

# %%
#plot count of cities by state
plt.figure(figsize=(20,10))
sns.countplot(x='ship-state',data=data)
plt.title('Distribution of state')
plt.xlabel('ship-city')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### from the graph we can say that most of the buyers are from maharashtra state

# %% [markdown]
# ## Conclusion:
# #### The data analysis reveals that the business has a isgnificant coustomers from maharashtra state, coustomers mainly order amazon shopping platform for order their required goods. Without that high amount of order is for kurta and set items and most of the goods are shipped
